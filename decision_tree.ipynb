# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv",sep = ';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
len(df['quality'].unique())
# Out:
# 6

# %%
df['quality'].nunique()
# Out:
# 6

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
demo_df=pd.DataFrame([1,2,3,3,23,2,1,2,123,333])

# %%
demo_df
# Out:
#      0
# 0    1
# 1    2
# 2    3
# 3    3
# 4   23
# 5    2
# 6    1
# 7    2
# 8  123
# 9  333

# %%
demo_df.duplicated().sum()
# Out:
# 4

# %%
X=df.drop("quality",axis=1)

# %%
y=df['quality']

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=10)

# %%
'''from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
sclr = StandardScaler()
scr.fit()
scr.transform()'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nfrom sklearn.preprocessing import StandardScaler\nsclr = StandardScaler()\nscr.fit()\nscr.transform()'

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model,filled=True)
# Out:
# [Text(684.0189813648955, 791.4176470588235, 'X[10] <= 10.15\ngini = 0.645\nsamples = 910\nvalue = [7, 31, 389, 359, 114, 10]'),
#  Text(315.4536404558046, 743.4529411764706, 'X[6] <= 62.5\ngini = 0.495\nsamples = 459\nvalue = [3, 15, 298, 131, 12, 0]'),
#  Text(164.2093458826492, 695.4882352941177, 'X[1] <= 0.548\ngini = 0.571\nsamples = 282\nvalue = [3, 11, 151, 105, 12, 0]'),
#  Text(84.57472928733316, 647.5235294117647, 'X[9] <= 0.585\ngini = 0.596\nsamples = 136\nvalue = [1, 4, 52, 68, 11, 0]'),
#  Text(28.103752203475196, 599.5588235294117, 'X[7] <= 0.996\ngini = 0.512\nsamples = 44\nvalue = [0, 4, 28, 12, 0, 0]'),
#  Text(11.241500881390078, 551.5941176470587, 'X[10] <= 9.125\ngini = 0.245\nsamples = 14\nvalue = [0, 2, 12, 0, 0, 0]'),
#  Text(5.620750440695039, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(16.862251322085115, 503.6294117647059, 'X[5] <= 21.5\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 12, 0, 0, 0]'),
#  Text(11.241500881390078, 455.66470588235296, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(22.483001762780155, 455.66470588235296, 'X[1] <= 0.345\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(16.862251322085115, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(28.103752203475196, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(44.96600352556031, 551.5941176470587, 'X[7] <= 0.996\ngini = 0.551\nsamples = 30\nvalue = [0, 2, 16, 12, 0, 0]'),
#  Text(39.34525308486527, 503.6294117647059, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(50.58675396625535, 503.6294117647059, 'X[6] <= 59.0\ngini = 0.532\nsamples = 27\nvalue = [0, 2, 16, 9, 0, 0]'),
#  Text(44.96600352556031, 455.66470588235296, 'X[3] <= 3.9\ngini = 0.506\nsamples = 25\nvalue = [0, 2, 16, 7, 0, 0]'),
#  Text(39.34525308486527, 407.7, 'X[3] <= 1.95\ngini = 0.469\nsamples = 24\nvalue = [0, 1, 16, 7, 0, 0]'),
#  Text(33.72450264417023, 359.7352941176471, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(44.96600352556031, 359.7352941176471, 'X[10] <= 9.05\ngini = 0.526\nsamples = 19\nvalue = [0, 1, 11, 7, 0, 0]'),
#  Text(39.34525308486527, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(50.58675396625535, 311.77058823529416, 'X[0] <= 10.65\ngini = 0.491\nsamples = 17\nvalue = [0, 1, 11, 5, 0, 0]'),
#  Text(44.96600352556031, 263.80588235294124, 'X[6] <= 52.0\ngini = 0.569\nsamples = 12\nvalue = [0, 1, 6, 5, 0, 0]'),
#  Text(39.34525308486527, 215.84117647058827, 'X[2] <= 0.145\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 3, 5, 0, 0]'),
#  Text(33.72450264417023, 167.8764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(44.96600352556031, 167.8764705882353, 'X[4] <= 0.102\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 1, 5, 0, 0]'),
#  Text(39.34525308486527, 119.91176470588243, 'X[2] <= 0.505\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(33.72450264417023, 71.94705882352946, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(44.96600352556031, 71.94705882352946, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(50.58675396625535, 119.91176470588243, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(50.58675396625535, 215.84117647058827, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(56.20750440695039, 263.80588235294124, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(50.58675396625535, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(56.20750440695039, 455.66470588235296, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(141.04570637119113, 599.5588235294117, 'X[7] <= 0.996\ngini = 0.547\nsamples = 92\nvalue = [1, 0, 24, 56, 11, 0]'),
#  Text(135.42495593049608, 551.5941176470587, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(146.66645681188618, 551.5941176470587, 'X[0] <= 11.35\ngini = 0.532\nsamples = 90\nvalue = [1, 0, 24, 56, 9, 0]'),
#  Text(119.08964996222613, 503.6294117647059, 'X[10] <= 9.95\ngini = 0.533\nsamples = 75\nvalue = [1, 0, 24, 45, 5, 0]'),
#  Text(80.79828758499119, 455.66470588235296, 'X[9] <= 0.615\ngini = 0.531\nsamples = 60\nvalue = [1, 0, 23, 34, 2, 0]'),
#  Text(61.828254847645425, 407.7, 'X[10] <= 9.6\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(56.20750440695039, 359.7352941176471, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(67.44900528834046, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(99.76832032233693, 407.7, 'X[9] <= 0.645\ngini = 0.532\nsamples = 53\nvalue = [1, 0, 23, 28, 1, 0]'),
#  Text(78.69050616973054, 359.7352941176471, 'X[4] <= 0.164\ngini = 0.461\nsamples = 16\nvalue = [0, 0, 11, 4, 1, 0]'),
#  Text(73.0697557290355, 311.77058823529416, 'X[8] <= 3.395\ngini = 0.357\nsamples = 14\nvalue = [0, 0, 11, 2, 1, 0]'),
#  Text(67.44900528834046, 263.80588235294124, 'X[1] <= 0.51\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 0, 1, 0]'),
#  Text(61.828254847645425, 215.84117647058827, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(73.0697557290355, 215.84117647058827, 'X[4] <= 0.078\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(67.44900528834046, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(78.69050616973054, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(78.69050616973054, 263.80588235294124, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(84.31125661042559, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(120.84613447494334, 359.7352941176471, 'X[4] <= 0.084\ngini = 0.473\nsamples = 37\nvalue = [1, 0, 12, 24, 0, 0]'),
#  Text(101.1735079325107, 311.77058823529416, 'X[5] <= 22.5\ngini = 0.278\nsamples = 18\nvalue = [0, 0, 3, 15, 0, 0]'),
#  Text(89.93200705112062, 263.80588235294124, 'X[2] <= 0.57\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 1, 14, 0, 0]'),
#  Text(84.31125661042559, 215.84117647058827, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(95.55275749181565, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(112.41500881390078, 263.80588235294124, 'X[3] <= 2.2\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(106.79425837320574, 215.84117647058827, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(118.03575925459582, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(140.51876101737597, 311.77058823529416, 'X[7] <= 0.998\ngini = 0.548\nsamples = 19\nvalue = [1, 0, 9, 9, 0, 0]'),
#  Text(134.89801057668092, 263.80588235294124, 'X[0] <= 7.6\ngini = 0.524\nsamples = 15\nvalue = [1, 0, 5, 9, 0, 0]'),
#  Text(129.2772601359859, 215.84117647058827, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(140.51876101737597, 215.84117647058827, 'X[9] <= 1.09\ngini = 0.403\nsamples = 12\nvalue = [1, 0, 2, 9, 0, 0]'),
#  Text(134.89801057668092, 167.8764705882353, 'X[7] <= 0.998\ngini = 0.18\nsamples = 10\nvalue = [1, 0, 0, 9, 0, 0]'),
#  Text(129.2772601359859, 119.91176470588243, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(140.51876101737597, 119.91176470588243, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(146.139511458071, 167.8764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(146.139511458071, 263.80588235294124, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(157.38101233946108, 455.66470588235296, 'X[6] <= 46.5\ngini = 0.418\nsamples = 15\nvalue = [0, 0, 1, 11, 3, 0]'),
#  Text(151.76026189876606, 407.7, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(163.00176278015613, 407.7, 'X[9] <= 0.625\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(157.38101233946108, 359.7352941176471, 'X[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(151.76026189876606, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(163.00176278015613, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(168.62251322085118, 359.7352941176471, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(174.2432636615462, 503.6294117647059, 'X[5] <= 8.0\ngini = 0.391\nsamples = 15\nvalue = [0, 0, 0, 11, 4, 0]'),
#  Text(168.62251322085118, 455.66470588235296, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(179.86401410224124, 455.66470588235296, 'X[1] <= 0.295\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 0, 3, 4, 0]'),
#  Text(174.2432636615462, 407.7, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(185.4847645429363, 407.7, 'X[10] <= 9.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(179.86401410224124, 359.7352941176471, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(191.1055149836313, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(243.84396247796525, 647.5235294117647, 'X[7] <= 0.996\ngini = 0.473\nsamples = 146\nvalue = [2, 7, 99, 37, 1, 0]'),
#  Text(202.3470158650214, 599.5588235294117, 'X[10] <= 9.15\ngini = 0.176\nsamples = 32\nvalue = [1, 1, 29, 1, 0, 0]'),
#  Text(191.1055149836313, 551.5941176470587, 'X[1] <= 0.695\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(185.4847645429363, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(196.72626542432636, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(213.58851674641147, 551.5941176470587, 'X[8] <= 3.515\ngini = 0.064\nsamples = 30\nvalue = [1, 0, 29, 0, 0, 0]'),
#  Text(207.96776630571642, 503.6294117647059, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28, 0, 0, 0]'),
#  Text(219.20926718710652, 503.6294117647059, 'X[0] <= 6.15\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(213.58851674641147, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(224.83001762780157, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(285.34090909090907, 599.5588235294117, 'X[10] <= 9.95\ngini = 0.52\nsamples = 114\nvalue = [1, 6, 70, 36, 1, 0]'),
#  Text(257.6762780156132, 551.5941176470587, 'X[8] <= 3.195\ngini = 0.487\nsamples = 95\nvalue = [1, 6, 63, 25, 0, 0]'),
#  Text(252.05552757491816, 503.6294117647059, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(263.2970284563082, 503.6294117647059, 'X[1] <= 0.688\ngini = 0.52\nsamples = 85\nvalue = [1, 6, 53, 25, 0, 0]'),
#  Text(236.07151850919163, 455.66470588235296, 'X[2] <= 0.28\ngini = 0.544\nsamples = 54\nvalue = [1, 2, 29, 22, 0, 0]'),
#  Text(219.56056408964994, 407.7, 'X[9] <= 0.535\ngini = 0.491\nsamples = 51\nvalue = [0, 0, 29, 22, 0, 0]'),
#  Text(203.4009065726517, 359.7352941176471, 'X[10] <= 9.7\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(197.7801561319567, 311.77058823529416, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(209.02165701334675, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(235.72022160664818, 359.7352941176471, 'X[2] <= 0.17\ngini = 0.5\nsamples = 43\nvalue = [0, 0, 22, 21, 0, 0]'),
#  Text(220.26315789473682, 311.77058823529416, 'X[8] <= 3.505\ngini = 0.489\nsamples = 33\nvalue = [0, 0, 14, 19, 0, 0]'),
#  Text(206.21128179299924, 263.80588235294124, 'X[5] <= 16.5\ngini = 0.444\nsamples = 27\nvalue = [0, 0, 9, 18, 0, 0]'),
#  Text(194.96978091160915, 215.84117647058827, 'X[6] <= 11.5\ngini = 0.332\nsamples = 19\nvalue = [0, 0, 4, 15, 0, 0]'),
#  Text(189.34903047091413, 167.8764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(200.5905313523042, 167.8764705882353, 'X[6] <= 53.5\ngini = 0.208\nsamples = 17\nvalue = [0, 0, 2, 15, 0, 0]'),
#  Text(194.96978091160915, 119.91176470588243, 'X[8] <= 3.475\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 1, 15, 0, 0]'),
#  Text(189.34903047091413, 71.94705882352946, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(200.5905313523042, 71.94705882352946, 'X[6] <= 38.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(194.96978091160915, 23.982352941176487, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(206.21128179299924, 23.982352941176487, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(206.21128179299924, 119.91176470588243, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(217.4527826743893, 215.84117647058827, 'X[4] <= 0.073\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 5, 3, 0, 0]'),
#  Text(211.83203223369426, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(223.07353311508436, 167.8764705882353, 'X[0] <= 7.65\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(217.4527826743893, 119.91176470588243, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(228.69428355577938, 119.91176470588243, 'X[3] <= 2.7\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(223.07353311508436, 71.94705882352946, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(234.31503399647443, 71.94705882352946, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(234.31503399647443, 263.80588235294124, 'X[9] <= 0.9\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(228.69428355577938, 215.84117647058827, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(239.93578443716947, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(251.17728531855954, 311.77058823529416, 'X[1] <= 0.555\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(245.55653487786452, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(256.79803575925456, 263.80588235294124, 'X[6] <= 61.0\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(251.17728531855954, 215.84117647058827, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(262.41878619994964, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(252.5824729287333, 407.7, 'X[0] <= 11.05\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0]'),
#  Text(246.96172248803828, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(258.2032233694284, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(290.52253840342485, 455.66470588235296, 'X[9] <= 0.465\ngini = 0.375\nsamples = 31\nvalue = [0, 4, 24, 3, 0, 0]'),
#  Text(284.90178796272977, 407.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(296.14328884411987, 407.7, 'X[0] <= 8.75\ngini = 0.3\nsamples = 29\nvalue = [0, 2, 24, 3, 0, 0]'),
#  Text(279.28103752203475, 359.7352941176471, 'X[10] <= 9.05\ngini = 0.15\nsamples = 25\nvalue = [0, 1, 23, 1, 0, 0]'),
#  Text(273.6602870813397, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(284.90178796272977, 311.77058823529416, 'X[6] <= 12.5\ngini = 0.08\nsamples = 24\nvalue = [0, 1, 23, 0, 0, 0]'),
#  Text(279.28103752203475, 263.80588235294124, 'X[0] <= 7.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(273.6602870813397, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(284.90178796272977, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(290.52253840342485, 263.80588235294124, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22, 0, 0, 0]'),
#  Text(313.005540166205, 359.7352941176471, 'X[3] <= 2.45\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]'),
#  Text(307.38478972550996, 311.77058823529416, 'X[0] <= 9.05\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(301.7640392848149, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(313.005540166205, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(318.6262906069, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(313.005540166205, 551.5941176470587, 'X[7] <= 0.997\ngini = 0.526\nsamples = 19\nvalue = [0, 0, 7, 11, 1, 0]'),
#  Text(307.38478972550996, 503.6294117647059, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(318.6262906069, 503.6294117647059, 'X[7] <= 0.998\ngini = 0.556\nsamples = 13\nvalue = [0, 0, 7, 5, 1, 0]'),
#  Text(313.005540166205, 455.66470588235296, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(324.2470410475951, 455.66470588235296, 'X[7] <= 0.999\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 2, 5, 1, 0]'),
#  Text(318.6262906069, 407.7, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(329.8677914882901, 407.7, 'X[0] <= 12.35\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(324.2470410475951, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(335.4885419289851, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(466.69793502895993, 695.4882352941177, 'X[6] <= 98.5\ngini = 0.288\nsamples = 177\nvalue = [0, 4, 147, 26, 0, 0]'),
#  Text(413.82775119617224, 647.5235294117647, 'X[10] <= 9.45\ngini = 0.39\nsamples = 116\nvalue = [0, 4, 87, 25, 0, 0]'),
#  Text(374.8337950138504, 599.5588235294117, 'X[8] <= 3.495\ngini = 0.222\nsamples = 49\nvalue = [0, 2, 43, 4, 0, 0]'),
#  Text(363.5922941324603, 551.5941176470587, 'X[4] <= 0.539\ngini = 0.163\nsamples = 46\nvalue = [0, 2, 42, 2, 0, 0]'),
#  Text(357.9715436917653, 503.6294117647059, 'X[5] <= 7.0\ngini = 0.126\nsamples = 45\nvalue = [0, 1, 42, 2, 0, 0]'),
#  Text(352.35079325107023, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(363.5922941324603, 455.66470588235296, 'X[5] <= 11.5\ngini = 0.088\nsamples = 44\nvalue = [0, 1, 42, 1, 0, 0]'),
#  Text(352.35079325107023, 407.7, 'X[5] <= 10.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(346.7300428103752, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(357.9715436917653, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(374.8337950138504, 407.7, 'X[2] <= 0.09\ngini = 0.048\nsamples = 41\nvalue = [0, 0, 40, 1, 0, 0]'),
#  Text(369.21304457315534, 359.7352941176471, 'X[1] <= 0.655\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(363.5922941324603, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(374.8337950138504, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(380.45454545454544, 359.7352941176471, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 38, 0, 0, 0]'),
#  Text(369.21304457315534, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(386.07529589524046, 551.5941176470587, 'X[5] <= 13.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(380.45454545454544, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(391.69604633593553, 503.6294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(452.82170737849407, 599.5588235294117, 'X[1] <= 0.415\ngini = 0.47\nsamples = 67\nvalue = [0, 2, 44, 21, 0, 0]'),
#  Text(408.55829765802065, 551.5941176470587, 'X[4] <= 0.072\ngini = 0.5\nsamples = 14\nvalue = [0, 1, 4, 9, 0, 0]'),
#  Text(402.9375472173256, 503.6294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(414.17904809871567, 503.6294117647059, 'X[6] <= 82.0\ngini = 0.403\nsamples = 12\nvalue = [0, 1, 2, 9, 0, 0]'),
#  Text(402.9375472173256, 455.66470588235296, 'X[8] <= 3.49\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 1, 9, 0, 0]'),
#  Text(397.31679677663055, 407.7, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(408.55829765802065, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(425.42054898010576, 455.66470588235296, 'X[8] <= 3.29\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(419.7997985394107, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(431.0412994208008, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(497.0851170989675, 551.5941176470587, 'X[8] <= 3.295\ngini = 0.379\nsamples = 53\nvalue = [0, 1, 40, 12, 0, 0]'),
#  Text(467.5761772853185, 503.6294117647059, 'X[8] <= 3.205\ngini = 0.5\nsamples = 26\nvalue = [0, 1, 16, 9, 0, 0]'),
#  Text(447.9035507428859, 455.66470588235296, 'X[3] <= 2.85\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]'),
#  Text(442.2828003021909, 407.7, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(453.5243011835809, 407.7, 'X[6] <= 82.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(447.9035507428859, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(459.145051624276, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(487.2488038277512, 455.66470588235296, 'X[3] <= 2.4\ngini = 0.556\nsamples = 13\nvalue = [0, 1, 5, 7, 0, 0]'),
#  Text(476.0073029463611, 407.7, 'X[1] <= 0.787\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(470.3865525056661, 359.7352941176471, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(481.6280533870561, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(498.49030470914124, 407.7, 'X[5] <= 29.5\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(492.8695542684462, 359.7352941176471, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(504.1110551498363, 359.7352941176471, 'X[1] <= 0.625\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(498.49030470914124, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(509.73180559053134, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(526.5940569126165, 503.6294117647059, 'X[2] <= 0.025\ngini = 0.198\nsamples = 27\nvalue = [0, 0, 24, 3, 0, 0]'),
#  Text(515.3525560312264, 455.66470588235296, 'X[10] <= 9.75\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(509.73180559053134, 407.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(520.9733064719214, 407.7, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(537.8355577940065, 455.66470588235296, 'X[3] <= 2.75\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(532.2148073533115, 407.7, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(543.4563082347015, 407.7, 'X[3] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(537.8355577940065, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(549.0770586753966, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(519.5681188617476, 647.5235294117647, 'X[4] <= 0.067\ngini = 0.032\nsamples = 61\nvalue = [0, 0, 60, 1, 0, 0]'),
#  Text(513.9473684210526, 599.5588235294117, 'X[10] <= 9.45\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(508.3266179803576, 551.5941176470587, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(519.5681188617476, 551.5941176470587, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(525.1888693024426, 599.5588235294117, 'gini = 0.0\nsamples = 59\nvalue = [0, 0, 59, 0, 0, 0]'),
#  Text(1052.5843222739863, 743.4529411764706, 'X[9] <= 0.675\ngini = 0.651\nsamples = 451\nvalue = [4, 16, 91, 228, 102, 10]'),
#  Text(836.8770460841098, 695.4882352941177, 'X[10] <= 11.45\ngini = 0.636\nsamples = 250\nvalue = [4, 16, 69, 130, 29, 2]'),
#  Text(722.7933769831277, 647.5235294117647, 'X[1] <= 0.827\ngini = 0.649\nsamples = 157\nvalue = [4, 13, 60, 69, 10, 1]'),
#  Text(623.9032989171493, 599.5588235294117, 'X[3] <= 1.85\ngini = 0.589\nsamples = 134\nvalue = [0, 3, 54, 66, 10, 1]'),
#  Text(577.1808108788719, 551.5941176470587, 'X[8] <= 3.355\ngini = 0.544\nsamples = 26\nvalue = [0, 0, 16, 6, 4, 0]'),
#  Text(565.9393099974817, 503.6294117647059, 'X[2] <= 0.405\ngini = 0.661\nsamples = 11\nvalue = [0, 0, 3, 4, 4, 0]'),
#  Text(560.3185595567867, 455.66470588235296, 'X[5] <= 15.0\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(554.6978091160917, 407.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(565.9393099974817, 407.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(571.5600604381767, 455.66470588235296, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(588.4223117602619, 503.6294117647059, 'X[8] <= 3.4\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(582.8015613195669, 455.66470588235296, 'X[1] <= 0.435\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(577.1808108788719, 407.7, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(588.4223117602619, 407.7, 'X[4] <= 0.074\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(582.8015613195669, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(594.0430622009569, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(594.0430622009569, 455.66470588235296, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(670.6257869554269, 551.5941176470587, 'X[7] <= 0.996\ngini = 0.564\nsamples = 108\nvalue = [0, 3, 38, 60, 6, 1]'),
#  Text(610.9053135230421, 503.6294117647059, 'X[9] <= 0.525\ngini = 0.373\nsamples = 38\nvalue = [0, 0, 8, 29, 1, 0]'),
#  Text(605.284563082347, 455.66470588235296, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(616.5260639637371, 455.66470588235296, 'X[6] <= 9.0\ngini = 0.292\nsamples = 35\nvalue = [0, 0, 5, 29, 1, 0]'),
#  Text(610.9053135230421, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(622.1468144044321, 407.7, 'X[7] <= 0.995\ngini = 0.251\nsamples = 34\nvalue = [0, 0, 5, 29, 0, 0]'),
#  Text(608.0949383026945, 359.7352941176471, 'X[5] <= 17.5\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(602.4741878619994, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(613.7156887433896, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(636.1986905061697, 359.7352941176471, 'X[5] <= 7.0\ngini = 0.18\nsamples = 30\nvalue = [0, 0, 3, 27, 0, 0]'),
#  Text(624.9571896247796, 311.77058823529416, 'X[9] <= 0.59\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(619.3364391840846, 263.80588235294124, 'X[1] <= 0.37\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(613.7156887433896, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(624.9571896247796, 215.84117647058827, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(630.5779400654746, 263.80588235294124, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(647.4401913875598, 311.77058823529416, 'X[6] <= 26.5\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 1, 23, 0, 0]'),
#  Text(641.8194409468648, 263.80588235294124, 'X[10] <= 10.3\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(636.1986905061697, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(647.4401913875598, 215.84117647058827, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(653.0609418282548, 263.80588235294124, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(730.3462603878116, 503.6294117647059, 'X[6] <= 42.5\ngini = 0.613\nsamples = 70\nvalue = [0, 3, 30, 31, 5, 1]'),
#  Text(700.8373205741626, 455.66470588235296, 'X[3] <= 2.15\ngini = 0.629\nsamples = 46\nvalue = [0, 2, 23, 15, 5, 1]'),
#  Text(689.5958196927726, 407.7, 'X[1] <= 0.27\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(683.9750692520776, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(695.2165701334676, 359.7352941176471, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(712.0788214555528, 407.7, 'X[1] <= 0.78\ngini = 0.616\nsamples = 40\nvalue = [0, 2, 22, 10, 5, 1]'),
#  Text(706.4580710148576, 359.7352941176471, 'X[10] <= 10.55\ngini = 0.6\nsamples = 38\nvalue = [0, 2, 22, 8, 5, 1]'),
#  Text(675.543943591035, 311.77058823529416, 'X[6] <= 37.5\ngini = 0.32\nsamples = 16\nvalue = [0, 0, 13, 2, 1, 0]'),
#  Text(664.3024427096449, 263.80588235294124, 'X[8] <= 3.485\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 12, 0, 1, 0]'),
#  Text(658.6816922689499, 215.84117647058827, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(669.9231931503399, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(686.7854444724251, 263.80588235294124, 'X[4] <= 0.09\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(681.16469403173, 215.84117647058827, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(692.4061949131201, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(737.3721984386804, 311.77058823529416, 'X[9] <= 0.625\ngini = 0.715\nsamples = 22\nvalue = [0, 2, 9, 6, 4, 1]'),
#  Text(714.8891966759003, 263.80588235294124, 'X[4] <= 0.081\ngini = 0.602\nsamples = 16\nvalue = [0, 1, 8, 6, 1, 0]'),
#  Text(703.6476957945101, 215.84117647058827, 'X[7] <= 0.996\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 0, 1, 0]'),
#  Text(698.0269453538151, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(709.2684462352053, 167.8764705882353, 'X[4] <= 0.058\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]'),
#  Text(703.6476957945101, 119.91176470588243, 'X[3] <= 2.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(698.0269453538151, 71.94705882352946, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(709.2684462352053, 71.94705882352946, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(714.8891966759003, 119.91176470588243, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(726.1306975572903, 215.84117647058827, 'X[4] <= 0.094\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 6, 0, 0]'),
#  Text(720.5099471165953, 167.8764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(731.7514479979853, 167.8764705882353, 'X[4] <= 0.103\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(726.1306975572903, 119.91176470588243, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(737.3721984386804, 119.91176470588243, 'X[3] <= 2.4\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(731.7514479979853, 71.94705882352946, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(742.9929488793755, 71.94705882352946, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(759.8552002014605, 263.80588235294124, 'X[6] <= 30.5\ngini = 0.667\nsamples = 6\nvalue = [0, 1, 1, 0, 3, 1]'),
#  Text(748.6136993200705, 215.84117647058827, 'X[1] <= 0.36\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 3, 1]'),
#  Text(742.9929488793755, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(754.2344497607655, 167.8764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(771.0967010828506, 215.84117647058827, 'X[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(765.4759506421556, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(776.7174515235457, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(717.6995718962478, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(759.8552002014605, 455.66470588235296, 'X[3] <= 2.05\ngini = 0.469\nsamples = 24\nvalue = [0, 1, 7, 16, 0, 0]'),
#  Text(748.6136993200705, 407.7, 'X[6] <= 54.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0, 0, 0]'),
#  Text(742.9929488793755, 359.7352941176471, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(754.2344497607655, 359.7352941176471, 'X[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(748.6136993200705, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(759.8552002014605, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(771.0967010828506, 407.7, 'X[5] <= 27.5\ngini = 0.266\nsamples = 19\nvalue = [0, 0, 3, 16, 0, 0]'),
#  Text(765.4759506421556, 359.7352941176471, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(776.7174515235457, 359.7352941176471, 'X[3] <= 2.85\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(771.0967010828506, 311.77058823529416, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(782.3382019642407, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(821.683455049106, 599.5588235294117, 'X[10] <= 10.95\ngini = 0.696\nsamples = 23\nvalue = [4, 10, 6, 3, 0, 0]'),
#  Text(799.2004532863258, 551.5941176470587, 'X[4] <= 0.075\ngini = 0.722\nsamples = 13\nvalue = [3, 2, 5, 3, 0, 0]'),
#  Text(782.3382019642407, 503.6294117647059, 'X[8] <= 3.52\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 0, 3, 0, 0]'),
#  Text(776.7174515235457, 455.66470588235296, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(787.9589524049358, 455.66470588235296, 'X[4] <= 0.064\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(782.3382019642407, 407.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(793.5797028456308, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(816.062704608411, 503.6294117647059, 'X[3] <= 3.275\ngini = 0.469\nsamples = 8\nvalue = [3, 0, 5, 0, 0, 0]'),
#  Text(810.441954167716, 455.66470588235296, 'X[6] <= 10.5\ngini = 0.278\nsamples = 6\nvalue = [1, 0, 5, 0, 0, 0]'),
#  Text(804.8212037270208, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(816.062704608411, 407.7, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(821.683455049106, 455.66470588235296, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(844.1664568118862, 551.5941176470587, 'X[2] <= 0.255\ngini = 0.34\nsamples = 10\nvalue = [1, 8, 1, 0, 0, 0]'),
#  Text(838.5457063711912, 503.6294117647059, 'X[6] <= 11.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8, 0, 0, 0, 0]'),
#  Text(832.924955930496, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(844.1664568118862, 455.66470588235296, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0, 0]'),
#  Text(849.7872072525812, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(950.9607151850919, 647.5235294117647, 'X[3] <= 4.5\ngini = 0.518\nsamples = 93\nvalue = [0, 3, 9, 61, 19, 1]'),
#  Text(911.6154621002266, 599.5588235294117, 'X[6] <= 15.5\ngini = 0.442\nsamples = 80\nvalue = [0, 1, 8, 58, 12, 1]'),
#  Text(875.0805842357089, 551.5941176470587, 'X[9] <= 0.545\ngini = 0.626\nsamples = 19\nvalue = [0, 1, 2, 9, 7, 0]'),
#  Text(861.0287081339712, 503.6294117647059, 'X[10] <= 12.6\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(855.4079576932762, 455.66470588235296, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(866.6494585746663, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(889.1324603374464, 503.6294117647059, 'X[7] <= 0.995\ngini = 0.583\nsamples = 12\nvalue = [0, 1, 1, 3, 7, 0]'),
#  Text(877.8909594560564, 455.66470588235296, 'X[6] <= 14.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 0, 6, 0]'),
#  Text(872.2702090153614, 407.7, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(883.5117098967514, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(900.3739612188365, 455.66470588235296, 'X[1] <= 0.54\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 3, 1, 0]'),
#  Text(894.7532107781415, 407.7, 'X[5] <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(889.1324603374464, 359.7352941176471, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(900.3739612188365, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(905.9947116595316, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(948.1503399647444, 551.5941176470587, 'X[5] <= 41.25\ngini = 0.338\nsamples = 61\nvalue = [0, 0, 6, 49, 5, 1]'),
#  Text(942.5295895240494, 503.6294117647059, 'X[4] <= 0.058\ngini = 0.316\nsamples = 60\nvalue = [0, 0, 6, 49, 5, 0]'),
#  Text(928.4777134223117, 455.66470588235296, 'X[5] <= 14.0\ngini = 0.475\nsamples = 18\nvalue = [0, 0, 5, 12, 1, 0]'),
#  Text(917.2362125409217, 407.7, 'X[1] <= 0.48\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(911.6154621002266, 359.7352941176471, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(922.8569629816167, 359.7352941176471, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(939.7192143037018, 407.7, 'X[10] <= 12.9\ngini = 0.292\nsamples = 12\nvalue = [0, 0, 1, 10, 1, 0]'),
#  Text(934.0984638630067, 359.7352941176471, 'X[6] <= 97.0\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(928.4777134223117, 311.77058823529416, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(939.7192143037018, 311.77058823529416, 'X[6] <= 107.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(934.0984638630067, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(945.3399647443969, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(945.3399647443969, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(956.5814656257869, 455.66470588235296, 'X[9] <= 0.605\ngini = 0.214\nsamples = 42\nvalue = [0, 0, 1, 37, 4, 0]'),
#  Text(950.9607151850919, 407.7, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 24, 0, 0]'),
#  Text(962.2022160664819, 407.7, 'X[10] <= 12.35\ngini = 0.426\nsamples = 18\nvalue = [0, 0, 1, 13, 4, 0]'),
#  Text(956.5814656257869, 359.7352941176471, 'X[7] <= 0.995\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 1, 5, 4, 0]'),
#  Text(950.9607151850919, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(962.2022160664819, 311.77058823529416, 'X[1] <= 0.46\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 1, 5, 2, 0]'),
#  Text(956.5814656257869, 263.80588235294124, 'X[2] <= 0.57\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 1, 2, 0]'),
#  Text(950.9607151850919, 215.84117647058827, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(962.2022160664819, 215.84117647058827, 'X[0] <= 10.6\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(956.5814656257869, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(967.822966507177, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(967.822966507177, 263.80588235294124, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(967.822966507177, 359.7352941176471, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(953.7710904054394, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(990.3059682699571, 599.5588235294117, 'X[2] <= 0.405\ngini = 0.627\nsamples = 13\nvalue = [0, 2, 1, 3, 7, 0]'),
#  Text(979.0644673885671, 551.5941176470587, 'X[5] <= 9.5\ngini = 0.64\nsamples = 5\nvalue = [0, 2, 1, 2, 0, 0]'),
#  Text(973.4437169478721, 503.6294117647059, 'X[10] <= 12.1\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(967.822966507177, 455.66470588235296, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(979.0644673885671, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(984.6852178292621, 503.6294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(1001.5474691513473, 551.5941176470587, 'X[1] <= 0.47\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(995.9267187106522, 503.6294117647059, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(1007.1682195920423, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1268.291598463863, 695.4882352941177, 'X[10] <= 12.05\ngini = 0.617\nsamples = 201\nvalue = [0, 0, 22, 98, 73, 8]'),
#  Text(1166.8765739108537, 647.5235294117647, 'X[1] <= 0.335\ngini = 0.589\nsamples = 164\nvalue = [0, 0, 21, 90, 50, 3]'),
#  Text(1056.3497859481238, 599.5588235294117, 'X[9] <= 0.735\ngini = 0.59\nsamples = 50\nvalue = [0, 0, 5, 18, 26, 1]'),
#  Text(1029.6512213548224, 551.5941176470587, 'X[5] <= 10.5\ngini = 0.5\nsamples = 12\nvalue = [0, 0, 2, 8, 2, 0]'),
#  Text(1018.4097204734323, 503.6294117647059, 'X[7] <= 0.995\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(1012.7889700327373, 455.66470588235296, 'X[2] <= 0.48\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(1007.1682195920423, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1018.4097204734323, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1024.0304709141274, 455.66470588235296, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(1040.8927222362124, 503.6294117647059, 'X[2] <= 0.695\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(1035.2719717955174, 455.66470588235296, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(1046.5134726769074, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1083.0483505414252, 551.5941176470587, 'X[10] <= 10.4\ngini = 0.525\nsamples = 38\nvalue = [0, 0, 3, 10, 24, 1]'),
#  Text(1063.3757239989927, 503.6294117647059, 'X[5] <= 36.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(1057.7549735582977, 455.66470588235296, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(1068.9964744396877, 455.66470588235296, 'X[5] <= 48.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(1063.3757239989927, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1074.6172248803828, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1102.7209770838579, 503.6294117647059, 'X[4] <= 0.12\ngini = 0.449\nsamples = 32\nvalue = [0, 0, 3, 5, 23, 1]'),
#  Text(1097.1002266431628, 455.66470588235296, 'X[6] <= 53.5\ngini = 0.391\nsamples = 30\nvalue = [0, 0, 3, 3, 23, 1]'),
#  Text(1085.8587257617728, 407.7, 'X[3] <= 1.65\ngini = 0.288\nsamples = 24\nvalue = [0, 0, 0, 3, 20, 1]'),
#  Text(1080.2379753210778, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1091.4794762024678, 359.7352941176471, 'X[2] <= 0.475\ngini = 0.234\nsamples = 23\nvalue = [0, 0, 0, 2, 20, 1]'),
#  Text(1085.8587257617728, 311.77058823529416, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 0, 14, 0]'),
#  Text(1097.1002266431628, 311.77058823529416, 'X[10] <= 11.45\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 2, 6, 1]'),
#  Text(1091.4794762024678, 263.80588235294124, 'X[2] <= 0.485\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 2, 6, 0]'),
#  Text(1085.8587257617728, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1097.1002266431628, 215.84117647058827, 'X[9] <= 0.845\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(1091.4794762024678, 167.8764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(1102.7209770838579, 167.8764705882353, 'X[9] <= 0.87\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(1097.1002266431628, 119.91176470588243, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1108.3417275245529, 119.91176470588243, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(1102.7209770838579, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1108.3417275245529, 407.7, 'X[6] <= 72.0\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 0, 3, 0]'),
#  Text(1102.7209770838579, 359.7352941176471, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(1113.962477965248, 359.7352941176471, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(1108.3417275245529, 455.66470588235296, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(1277.4033618735834, 599.5588235294117, 'X[3] <= 4.4\ngini = 0.537\nsamples = 114\nvalue = [0, 0, 16, 72, 24, 2]'),
#  Text(1238.4972299168974, 551.5941176470587, 'X[2] <= 0.56\ngini = 0.484\nsamples = 104\nvalue = [0, 0, 10, 71, 21, 2]'),
#  Text(1214.0820951901285, 503.6294117647059, 'X[1] <= 0.875\ngini = 0.431\nsamples = 90\nvalue = [0, 0, 9, 66, 13, 2]'),
#  Text(1208.4613447494332, 455.66470588235296, 'X[4] <= 0.071\ngini = 0.409\nsamples = 88\nvalue = [0, 0, 7, 66, 13, 2]'),
#  Text(1184.924452279023, 407.7, 'X[1] <= 0.555\ngini = 0.542\nsamples = 34\nvalue = [0, 0, 2, 21, 9, 2]'),
#  Text(1165.9544195416772, 359.7352941176471, 'X[6] <= 47.5\ngini = 0.464\nsamples = 27\nvalue = [0, 0, 1, 19, 5, 2]'),
#  Text(1144.8766053890706, 311.77058823529416, 'X[7] <= 0.996\ngini = 0.602\nsamples = 16\nvalue = [0, 0, 1, 9, 4, 2]'),
#  Text(1130.8247292873332, 263.80588235294124, 'X[2] <= 0.285\ngini = 0.716\nsamples = 9\nvalue = [0, 0, 1, 3, 3, 2]'),
#  Text(1119.5832284059431, 215.84117647058827, 'X[3] <= 2.15\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(1113.962477965248, 167.8764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(1125.2039788466382, 167.8764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1142.0662301687232, 215.84117647058827, 'X[2] <= 0.405\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 0, 3, 2]'),
#  Text(1136.4454797280282, 167.8764705882353, 'X[2] <= 0.305\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2]'),
#  Text(1130.8247292873332, 119.91176470588243, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1142.0662301687232, 119.91176470588243, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(1147.6869806094182, 167.8764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(1158.9284814908083, 263.80588235294124, 'X[4] <= 0.061\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(1153.3077310501133, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1164.5492319315033, 215.84117647058827, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(1187.0322336942836, 311.77058823529416, 'X[8] <= 3.19\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(1181.4114832535886, 263.80588235294124, 'X[2] <= 0.405\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(1175.7907328128933, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1187.0322336942836, 215.84117647058827, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1192.6529841349786, 263.80588235294124, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(1203.8944850163687, 359.7352941176471, 'X[4] <= 0.061\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 2, 4, 0]'),
#  Text(1198.2737345756736, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(1209.5152354570637, 311.77058823529416, 'X[0] <= 10.25\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(1203.8944850163687, 263.80588235294124, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(1215.1359858977587, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1231.9982372198438, 407.7, 'X[7] <= 1.002\ngini = 0.291\nsamples = 54\nvalue = [0, 0, 5, 45, 4, 0]'),
#  Text(1226.3774867791487, 359.7352941176471, 'X[0] <= 6.0\ngini = 0.268\nsamples = 53\nvalue = [0, 0, 4, 45, 4, 0]'),
#  Text(1220.7567363384537, 311.77058823529416, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1231.9982372198438, 311.77058823529416, 'X[1] <= 0.345\ngini = 0.242\nsamples = 52\nvalue = [0, 0, 3, 45, 4, 0]'),
#  Text(1226.3774867791487, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1237.6189876605388, 263.80588235294124, 'X[9] <= 0.845\ngini = 0.214\nsamples = 51\nvalue = [0, 0, 2, 45, 4, 0]'),
#  Text(1217.9463611181063, 215.84117647058827, 'X[4] <= 0.123\ngini = 0.141\nsamples = 40\nvalue = [0, 0, 1, 37, 2, 0]'),
#  Text(1206.704860236716, 167.8764705882353, 'X[10] <= 11.65\ngini = 0.1\nsamples = 38\nvalue = [0, 0, 0, 36, 2, 0]'),
#  Text(1201.084109796021, 119.91176470588243, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 0, 31, 0, 0]'),
#  Text(1212.325610677411, 119.91176470588243, 'X[2] <= 0.39\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]'),
#  Text(1206.704860236716, 71.94705882352946, 'X[7] <= 0.996\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(1201.084109796021, 23.982352941176487, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1212.325610677411, 23.982352941176487, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(1217.9463611181063, 71.94705882352946, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(1229.1878619994964, 167.8764705882353, 'X[7] <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(1223.5671115588013, 119.91176470588243, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1234.8086124401914, 119.91176470588243, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1257.2916142029715, 215.84117647058827, 'X[9] <= 0.885\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 1, 8, 2, 0]'),
#  Text(1251.6708637622764, 167.8764705882353, 'X[8] <= 3.305\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 1, 2, 0]'),
#  Text(1246.0501133215814, 119.91176470588243, 'X[3] <= 2.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(1240.4293628808864, 71.94705882352946, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1251.6708637622764, 71.94705882352946, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1257.2916142029715, 119.91176470588243, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(1262.9123646436665, 167.8764705882353, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(1237.6189876605388, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1219.7028456308235, 455.66470588235296, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(1262.9123646436665, 503.6294117647059, 'X[7] <= 0.998\ngini = 0.541\nsamples = 14\nvalue = [0, 0, 1, 5, 8, 0]'),
#  Text(1248.860488541929, 455.66470588235296, 'X[4] <= 0.147\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(1243.2397381012338, 407.7, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(1254.481238982624, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1276.9642407454041, 455.66470588235296, 'X[10] <= 10.65\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 4, 2, 0]'),
#  Text(1265.722739864014, 407.7, 'X[2] <= 0.63\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(1260.101989423319, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1271.3434903047091, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1288.2057416267942, 407.7, 'X[8] <= 2.98\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(1282.5849911860992, 359.7352941176471, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1293.8264920674892, 359.7352941176471, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(1316.3094938302695, 551.5941176470587, 'X[6] <= 52.5\ngini = 0.54\nsamples = 10\nvalue = [0, 0, 6, 1, 3, 0]'),
#  Text(1310.6887433895743, 503.6294117647059, 'X[8] <= 3.285\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(1305.0679929488792, 455.66470588235296, 'X[10] <= 11.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(1299.4472425081842, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1310.6887433895743, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1316.3094938302695, 455.66470588235296, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(1321.9302442709645, 503.6294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(1369.7066230168723, 647.5235294117647, 'X[9] <= 0.905\ngini = 0.548\nsamples = 37\nvalue = [0, 0, 1, 8, 23, 5]'),
#  Text(1364.0858725761773, 599.5588235294117, 'X[10] <= 13.8\ngini = 0.498\nsamples = 34\nvalue = [0, 0, 1, 5, 23, 5]'),
#  Text(1344.4132460337446, 551.5941176470587, 'X[2] <= 0.565\ngini = 0.4\nsamples = 29\nvalue = [0, 0, 1, 2, 22, 4]'),
#  Text(1333.1717451523546, 503.6294117647059, 'X[3] <= 6.3\ngini = 0.313\nsamples = 27\nvalue = [0, 0, 0, 1, 22, 4]'),
#  Text(1327.5509947116595, 455.66470588235296, 'X[5] <= 31.5\ngini = 0.269\nsamples = 26\nvalue = [0, 0, 0, 1, 22, 3]'),
#  Text(1321.9302442709645, 407.7, 'X[4] <= 0.076\ngini = 0.218\nsamples = 25\nvalue = [0, 0, 0, 1, 22, 2]'),
#  Text(1310.6887433895743, 359.7352941176471, 'X[9] <= 0.705\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 0, 1, 18, 0]'),
#  Text(1305.0679929488792, 311.77058823529416, 'X[1] <= 0.385\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(1299.4472425081842, 263.80588235294124, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(1310.6887433895743, 263.80588235294124, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1316.3094938302695, 311.77058823529416, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 0, 16, 0]'),
#  Text(1333.1717451523546, 359.7352941176471, 'X[10] <= 12.7\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 0, 4, 2]'),
#  Text(1327.5509947116595, 311.77058823529416, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(1338.7924955930496, 311.77058823529416, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(1333.1717451523546, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1338.7924955930496, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1355.6547469151346, 503.6294117647059, 'X[2] <= 0.695\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(1350.0339964744396, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1361.2754973558297, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1383.75849911861, 551.5941176470587, 'X[1] <= 0.475\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 0, 3, 1, 1]'),
#  Text(1378.137748677915, 503.6294117647059, 'X[0] <= 4.95\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(1372.5169982372197, 455.66470588235296, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1383.75849911861, 455.66470588235296, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(1389.379249559305, 503.6294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1375.3273734575673, 599.5588235294117, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]')]

# %%
fig.savefig("decistion_tree_classifier.png")

# %%
y_predict=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.5077951002227171

# %%
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,10,1),
    'min_samples_leaf' : range(1,8,1),
    'min_samples_split': range(2,8,1),
    'splitter' : ['best', 'random']
    
}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=model,param_grid=grid_param,cv=3,verbose=1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 8),
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_searh.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 6,
#  'min_samples_split': 5,
#  'splitter': 'random'}

# %%
model_with_best_params=DecisionTreeClassifier(criterion= 'gini',max_depth= 6,min_samples_leaf= 4,min_samples_split= 6,splitter='random')

# %%
model_with_best_params.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=4, min_samples_split=6,
#                        splitter='random')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model_with_best_params,filled=True,fontsize=10)
# Out:
# [Text(812.8125, 757.1571428571428, 'X[10] <= 11.596\ngini = 0.645\nsamples = 910\nvalue = [7, 31, 389, 359, 114, 10]'),
#  Text(466.875, 640.6714285714286, 'X[10] <= 9.478\ngini = 0.607\nsamples = 760\nvalue = [7, 30, 378, 282, 61, 2]'),
#  Text(208.125, 524.1857142857143, 'X[5] <= 10.781\ngini = 0.411\nsamples = 186\nvalue = [1, 5, 136, 43, 1, 0]'),
#  Text(67.5, 407.7, 'X[5] <= 4.383\ngini = 0.555\nsamples = 49\nvalue = [1, 1, 25, 21, 1, 0]'),
#  Text(45.0, 291.21428571428567, 'gini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(90.0, 291.21428571428567, 'X[6] <= 23.631\ngini = 0.567\nsamples = 42\nvalue = [1, 1, 19, 20, 1, 0]'),
#  Text(45.0, 174.7285714285714, 'X[5] <= 7.302\ngini = 0.533\nsamples = 22\nvalue = [0, 1, 12, 9, 0, 0]'),
#  Text(22.5, 58.24285714285713, 'gini = 0.43\nsamples = 16\nvalue = [0, 0, 11, 5, 0, 0]'),
#  Text(67.5, 58.24285714285713, 'gini = 0.5\nsamples = 6\nvalue = [0, 1, 1, 4, 0, 0]'),
#  Text(135.0, 174.7285714285714, 'X[6] <= 31.345\ngini = 0.57\nsamples = 20\nvalue = [1, 0, 7, 11, 1, 0]'),
#  Text(112.5, 58.24285714285713, 'gini = 0.37\nsamples = 9\nvalue = [0, 0, 1, 7, 1, 0]'),
#  Text(157.5, 58.24285714285713, 'gini = 0.562\nsamples = 11\nvalue = [1, 0, 6, 4, 0, 0]'),
#  Text(348.75, 407.7, 'X[6] <= 97.067\ngini = 0.317\nsamples = 137\nvalue = [0, 4, 111, 22, 0, 0]'),
#  Text(270.0, 291.21428571428567, 'X[5] <= 17.676\ngini = 0.392\nsamples = 100\nvalue = [0, 4, 75, 21, 0, 0]'),
#  Text(225.0, 174.7285714285714, 'X[10] <= 9.3\ngini = 0.475\nsamples = 54\nvalue = [0, 3, 36, 15, 0, 0]'),
#  Text(202.5, 58.24285714285713, 'gini = 0.528\nsamples = 38\nvalue = [0, 3, 23, 12, 0, 0]'),
#  Text(247.5, 58.24285714285713, 'gini = 0.305\nsamples = 16\nvalue = [0, 0, 13, 3, 0, 0]'),
#  Text(315.0, 174.7285714285714, 'X[0] <= 8.185\ngini = 0.264\nsamples = 46\nvalue = [0, 1, 39, 6, 0, 0]'),
#  Text(292.5, 58.24285714285713, 'gini = 0.17\nsamples = 32\nvalue = [0, 0, 29, 3, 0, 0]'),
#  Text(337.5, 58.24285714285713, 'gini = 0.439\nsamples = 14\nvalue = [0, 1, 10, 3, 0, 0]'),
#  Text(427.5, 291.21428571428567, 'X[5] <= 22.49\ngini = 0.053\nsamples = 37\nvalue = [0, 0, 36, 1, 0, 0]'),
#  Text(405.0, 174.7285714285714, 'X[4] <= 0.086\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(382.5, 58.24285714285713, 'gini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(427.5, 58.24285714285713, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(450.0, 174.7285714285714, 'gini = 0.0\nsamples = 29\nvalue = [0, 0, 29, 0, 0, 0]'),
#  Text(725.625, 524.1857142857143, 'X[10] <= 11.205\ngini = 0.636\nsamples = 574\nvalue = [6, 25, 242, 239, 60, 2]'),
#  Text(618.75, 407.7, 'X[6] <= 112.676\ngini = 0.628\nsamples = 520\nvalue = [6, 21, 234, 207, 51, 1]'),
#  Text(540.0, 291.21428571428567, 'X[4] <= 0.089\ngini = 0.634\nsamples = 497\nvalue = [6, 21, 212, 206, 51, 1]'),
#  Text(495.0, 174.7285714285714, 'X[9] <= 0.671\ngini = 0.632\nsamples = 353\nvalue = [3, 16, 138, 159, 36, 1]'),
#  Text(472.5, 58.24285714285713, 'gini = 0.599\nsamples = 234\nvalue = [3, 15, 118, 88, 9, 1]'),
#  Text(517.5, 58.24285714285713, 'gini = 0.564\nsamples = 119\nvalue = [0, 1, 20, 71, 27, 0]'),
#  Text(585.0, 174.7285714285714, 'X[1] <= 0.434\ngini = 0.617\nsamples = 144\nvalue = [3, 5, 74, 47, 15, 0]'),
#  Text(562.5, 58.24285714285713, 'gini = 0.654\nsamples = 41\nvalue = [0, 0, 15, 16, 10, 0]'),
#  Text(607.5, 58.24285714285713, 'gini = 0.576\nsamples = 103\nvalue = [3, 5, 59, 31, 5, 0]'),
#  Text(697.5, 291.21428571428567, 'X[1] <= 0.453\ngini = 0.083\nsamples = 23\nvalue = [0, 0, 22, 1, 0, 0]'),
#  Text(675.0, 174.7285714285714, 'X[4] <= 0.078\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(652.5, 58.24285714285713, 'gini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(697.5, 58.24285714285713, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(720.0, 174.7285714285714, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(832.5, 407.7, 'X[8] <= 3.539\ngini = 0.593\nsamples = 54\nvalue = [0, 4, 8, 32, 9, 1]'),
#  Text(810.0, 291.21428571428567, 'X[0] <= 7.304\ngini = 0.567\nsamples = 47\nvalue = [0, 3, 5, 29, 9, 1]'),
#  Text(765.0, 174.7285714285714, 'X[2] <= 0.384\ngini = 0.436\nsamples = 15\nvalue = [0, 2, 0, 11, 1, 1]'),
#  Text(742.5, 58.24285714285713, 'gini = 0.545\nsamples = 11\nvalue = [0, 2, 0, 7, 1, 1]'),
#  Text(787.5, 58.24285714285713, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(855.0, 174.7285714285714, 'X[2] <= 0.403\ngini = 0.596\nsamples = 32\nvalue = [0, 1, 5, 18, 8, 0]'),
#  Text(832.5, 58.24285714285713, 'gini = 0.625\nsamples = 12\nvalue = [0, 1, 1, 4, 6, 0]'),
#  Text(877.5, 58.24285714285713, 'gini = 0.46\nsamples = 20\nvalue = [0, 0, 4, 14, 2, 0]'),
#  Text(855.0, 291.21428571428567, 'gini = 0.612\nsamples = 7\nvalue = [0, 1, 3, 3, 0, 0]'),
#  Text(1158.75, 640.6714285714286, 'X[9] <= 0.582\ngini = 0.603\nsamples = 150\nvalue = [0, 1, 11, 77, 53, 8]'),
#  Text(1046.25, 524.1857142857143, 'X[2] <= 0.397\ngini = 0.517\nsamples = 38\nvalue = [0, 1, 6, 25, 6, 0]'),
#  Text(967.5, 407.7, 'X[5] <= 8.248\ngini = 0.472\nsamples = 21\nvalue = [0, 0, 6, 14, 1, 0]'),
#  Text(922.5, 291.21428571428567, 'X[9] <= 0.506\ngini = 0.568\nsamples = 9\nvalue = [0, 0, 5, 3, 1, 0]'),
#  Text(900.0, 174.7285714285714, 'gini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(945.0, 174.7285714285714, 'gini = 0.64\nsamples = 5\nvalue = [0, 0, 2, 2, 1, 0]'),
#  Text(1012.5, 291.21428571428567, 'X[0] <= 6.6\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11, 0, 0]'),
#  Text(990.0, 174.7285714285714, 'gini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(1035.0, 174.7285714285714, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(1125.0, 407.7, 'X[3] <= 4.477\ngini = 0.491\nsamples = 17\nvalue = [0, 1, 0, 11, 5, 0]'),
#  Text(1102.5, 291.21428571428567, 'X[10] <= 12.292\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(1080.0, 174.7285714285714, 'gini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(1125.0, 174.7285714285714, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(1147.5, 291.21428571428567, 'gini = 0.5\nsamples = 6\nvalue = [0, 1, 0, 1, 4, 0]'),
#  Text(1271.25, 524.1857142857143, 'X[2] <= 0.657\ngini = 0.601\nsamples = 112\nvalue = [0, 0, 5, 52, 47, 8]'),
#  Text(1248.75, 407.7, 'X[9] <= 0.733\ngini = 0.592\nsamples = 105\nvalue = [0, 0, 3, 48, 46, 8]'),
#  Text(1192.5, 291.21428571428567, 'X[2] <= 0.463\ngini = 0.573\nsamples = 56\nvalue = [0, 0, 3, 31, 19, 3]'),
#  Text(1170.0, 174.7285714285714, 'X[10] <= 12.649\ngini = 0.55\nsamples = 47\nvalue = [0, 0, 3, 28, 14, 2]'),
#  Text(1147.5, 58.24285714285713, 'gini = 0.462\nsamples = 35\nvalue = [0, 0, 1, 24, 9, 1]'),
#  Text(1192.5, 58.24285714285713, 'gini = 0.681\nsamples = 12\nvalue = [0, 0, 2, 4, 5, 1]'),
#  Text(1215.0, 174.7285714285714, 'gini = 0.568\nsamples = 9\nvalue = [0, 0, 0, 3, 5, 1]'),
#  Text(1305.0, 291.21428571428567, 'X[3] <= 1.959\ngini = 0.566\nsamples = 49\nvalue = [0, 0, 0, 17, 27, 5]'),
#  Text(1260.0, 174.7285714285714, 'X[10] <= 12.835\ngini = 0.54\nsamples = 10\nvalue = [0, 0, 0, 6, 3, 1]'),
#  Text(1237.5, 58.24285714285713, 'gini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(1282.5, 58.24285714285713, 'gini = 0.64\nsamples = 5\nvalue = [0, 0, 0, 2, 2, 1]'),
#  Text(1350.0, 174.7285714285714, 'X[7] <= 0.996\ngini = 0.531\nsamples = 39\nvalue = [0, 0, 0, 11, 24, 4]'),
#  Text(1327.5, 58.24285714285713, 'gini = 0.368\nsamples = 22\nvalue = [0, 0, 0, 4, 17, 1]'),
#  Text(1372.5, 58.24285714285713, 'gini = 0.63\nsamples = 17\nvalue = [0, 0, 0, 7, 7, 3]'),
#  Text(1293.75, 407.7, 'gini = 0.571\nsamples = 7\nvalue = [0, 0, 2, 4, 1, 0]')]

# %%
y_prediction2=model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_prediction2)
# Out:
# 0.5189309576837416

# %%
#logistic regression, SVM ,  going forward(RF,XB,GB,AB)

# %%
#Implement the decision tree regressor
dataset:https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
        
take_refrence_from_here:https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor
# Out:
#   File "<ipython-input-37-0928058142ba>", line 2
#     dataset:https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
#                  ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import RandomForestClassifier
Rf_model=RandomForestClassifier()

# %%
Rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=Rf_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.6169265033407573

# %%
# we are tuning three hyperparameters right now, we are passing the different values for both parameters
grid_param = {
    "n_estimators" : [90,100,115,130],
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,20,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'max_features' : ['auto','log2']
}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=Rf_model,param_grid=grid_param,cv=3,verbose=2,n_jobs=-1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 20736 candidates, totalling 62208 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 20),
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'n_estimators': [90, 100, 115, 130]},
#              verbose=2)

# %%
grid_searh.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 19,
#  'max_features': 'log2',
#  'min_samples_leaf': 2,
#  'min_samples_split': 7,
#  'n_estimators': 130}

# %%
Rf_model_with_best_params=RandomForestClassifier(criterion='gini',max_depth= 14,max_features= 'log2',min_samples_leaf= 1,min_samples_split= 2,n_estimators=115)

# %%
Rf_model_with_best_params.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=14, max_features='log2', n_estimators=115)

# %%
y_predict_rf_bp=Rf_model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_predict_rf_bp)
# Out:
# 0.5924276169265034

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.datasets import make_classification

model_bagging_svc = BaggingClassifier(base_estimator=SVC(),n_estimators=50, random_state=0).fit(X_train,y_train)

# %%
y_predict_bagging=model_bagging_svc.predict(X_test)

# %%
accuracy_score(y_test,y_predict_bagging)
# Out:
# 0.4766146993318486

# %%
#use bagging classiifer and regressor, extra tree classifier and regressor, voting classifer and regressor and random forest classifier and regressor on top of House hold consumpltion data and cencus data

data link: https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
        https://archive.ics.uci.edu/ml/datasets/census+income
    
sklearn_link:https://scikit-learn.org/stable/modules/classes.html#module-sklearn.ensemble
# Out:
#   File "<ipython-input-64-3e5da89641ac>", line 3
#     data link: https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
#          ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import AdaBoostClassifier
model=AdaBoostClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_ada=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.6169265033407573
